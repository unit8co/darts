# %% [markdown]
# # Probabilistic RNN
# In this notebook, we show an example of how a probabilistic RNN can be used with darts.
# This type of RNN was inspired by, and is almost identical to DeepAR: https://arxiv.org/abs/1704.04110

# %%
# fix python path if working locally
from utils import fix_pythonpath_if_working_locally

fix_pythonpath_if_working_locally()

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import shutil
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm_notebook as tqdm

from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt

from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.models import RNNModel, ExponentialSmoothing, BlockRNNModel
from darts.metrics import mape
from darts.utils.statistics import check_seasonality, plot_acf
import darts.utils.timeseries_generation as tg
from darts.datasets import AirPassengersDataset, EnergyDataset
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.utils.missing_values import fill_missing_values
from darts.utils.likelihood_models import GaussianLikelihood
from darts.timeseries import concatenate
import warnings

warnings.filterwarnings("ignore")
import logging

logging.disable(logging.CRITICAL)

# %% [markdown]
# ## Variable noise series
# As a toy example we create a target time series that is created by taking the some of a sine wave and a gaussian noise series. To make things interesting, the intensity of the gaussian noise is also modulated by a sine wave (with a different frequency). This means that the effect of the noise gets stronger and weaker in an oscillating fashion. The idea is to test whether a probabilistic RNN can model this oscillating uncertainty in its predictions.

# %%
length = 400
trend = tg.linear_timeseries(length=length, end_value=4)
season1 = tg.sine_timeseries(length=length, value_frequency=0.05, value_amplitude=1.0)
noise = tg.gaussian_timeseries(length=length, std=0.6)
noise_modulator = (
    tg.sine_timeseries(length=length, value_frequency=0.02)
    + tg.constant_timeseries(length=length, value=1)
) / 2
noise = noise * noise_modulator

target_series = sum([noise, season1])
covariates = noise_modulator
target_train, target_val = target_series.split_after(0.65)

# %%
target_train.plot()
target_val.plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# In the following we train a probabilistic RNN to predict the targets series in an autoregressive fashion, but also by taking into consideration the modulation of the noise component as a covariate which is known in the future. So the RNN has information on when the noise component of the target is severe, but it doesn't know the noise component itself. Let's see if the RNN can make use of this information.

# %%
my_model = RNNModel(
    model="LSTM",
    hidden_dim=20,
    dropout=0,
    batch_size=16,
    n_epochs=50,
    optimizer_kwargs={"lr": 1e-3},
    random_state=0,
    training_length=50,
    input_chunk_length=20,
    likelihood=GaussianLikelihood(),
)

my_model.fit(target_train, future_covariates=covariates, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 14
#       1 my_model = RNNModel(
#       2     model="LSTM",
#       3     hidden_dim=20,
#    (...)
#      11     likelihood=GaussianLikelihood(),
#      12 )
# ---> 14 my_model.fit(target_train, future_covariates=covariates, verbose=True)
#
# File ~/Desktop/darts/darts/utils/torch.py:112, in random_method.<locals>.decorator(self, *args, **kwargs)
#     110 with fork_rng():
#     111     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 112     return decorated(self, *args, **kwargs)
#
# File ~/Desktop/darts/darts/models/forecasting/torch_forecasting_model.py:681, in TorchForecastingModel.fit(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, trainer, verbose, epochs, max_samples_per_ts, num_loader_workers)
#     600 @random_method
#     601 def fit(
#     602     self,
#    (...)
#     613     num_loader_workers: int = 0,
#     614 ) -> "TorchForecastingModel":
#     615     """Fit/train the model on one or multiple series.
#     616
#     617     This method wraps around :func:`fit_from_dataset()`, constructing a default training
#    (...)
#     675         Fitted model.
#     676     """
#     677     (
#     678         series,
#     679         past_covariates,
#     680         future_covariates,
# --> 681     ), params = self._setup_for_fit_from_dataset(
#     682         series=series,
#     683         past_covariates=past_covariates,
#     684         future_covariates=future_covariates,
#     685         val_series=val_series,
#     686         val_past_covariates=val_past_covariates,
#     687         val_future_covariates=val_future_covariates,
#     688         trainer=trainer,
#     689         verbose=verbose,
#     690         epochs=epochs,
#     691         max_samples_per_ts=max_samples_per_ts,
#     692         num_loader_workers=num_loader_workers,
#     693     )
#     694     # call super fit only if user is actually fitting the model
#     695     super().fit(
#     696         series=seq2series(series),
#     697         past_covariates=seq2series(past_covariates),
#     698         future_covariates=seq2series(future_covariates),
#     699     )
#
# File ~/Desktop/darts/darts/models/forecasting/torch_forecasting_model.py:830, in TorchForecastingModel._setup_for_fit_from_dataset(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, trainer, verbose, epochs, max_samples_per_ts, num_loader_workers)
#     828 except ValueError:
#     829     length_ok = False
# --> 830 raise_if(
#     831     not length_ok or len(train_dataset) == 0,  # mind the order
#     832     "The train dataset does not contain even one training sample. "
#     833     + "This is likely due to the provided training series being too short. "
#     834     + "This model expect series of length at least {}.".format(
#     835         self.min_train_series_length
#     836     ),
#     837 )
#     838 logger.info(f"Train dataset contains {len(train_dataset)} samples.")
#     839 series_input = (series, past_covariates, future_covariates)
#
# File ~/Desktop/darts/darts/logging.py:104, in raise_if(condition, message, logger)
#      81 def raise_if(
#      82     condition: bool,
#      83     message: str = "",
#      84     logger: logging.Logger = get_logger("main_logger"),
#      85 ):
#      86     """
#      87     Checks provided boolean condition and raises a ValueError if it evaluates to True.
#      88     It logs the error to the provided logger before raising it.
#    (...)
#     102         if `condition` is satisfied
#     103     """
# --> 104     raise_if_not(not condition, message, logger)
#
# File ~/Desktop/darts/darts/logging.py:78, in raise_if_not(condition, message, logger)
#      76 if not condition:
#      77     logger.error("ValueError: " + message)
# ---> 78     raise ValueError(message)
#
# ValueError: The train dataset does not contain even one training sample. This is likely due to the provided training series being too short. This model expect series of length at least 51.

# %%
pred = my_model.predict(80, num_samples=50)
target_val.slice_intersect(pred).plot(label="target")
pred.plot(label="prediction")
# Out:
# Predicting: 0it [00:00, ?it/s]
# <Axes: xlabel='time'>

# %% [markdown]
# We can see that, on top of correctly predicting the, granted, simple oscillatory behavior of the target, the RNN correctly expresses more uncertainty in its predictions when the noise component is higher.

# %% [markdown]
# ## Daily energy production

# %%
df3 = EnergyDataset().load().pd_dataframe()
df3_day_avg = (
    df3.groupby(df3.index.astype(str).str.split(" ").str[0]).mean().reset_index()
)
series_en = fill_missing_values(
    TimeSeries.from_dataframe(
        df3_day_avg, "time", ["generation hydro run-of-river and poundage"]
    ),
    "auto",
)

# convert to float32
series_en = series_en.astype(np.float32)

train_en, val_en = series_en.split_after(pd.Timestamp("20170901"))

# scale
scaler_en = Scaler()

train_en_transformed = scaler_en.fit_transform(train_en)
val_en_transformed = scaler_en.transform(val_en)

# add the day as a covariate
day_series = datetime_attribute_timeseries(
    series_en, attribute="day", one_hot=True, dtype=np.float32
)
train, val = day_series.split_after(pd.Timestamp("20170901"))

scaler_day = Scaler()

train_day = scaler_day.fit_transform(train)
val_day = scaler_day.transform(val)


train_en_transformed.plot(label="train")
val_en_transformed.plot(label="validation")
# Out:
# <Axes: xlabel='time'>

# %%
model_en = RNNModel(
    model="LSTM",
    hidden_dim=20,
    n_rnn_layers=2,
    dropout=0.2,
    batch_size=16,
    n_epochs=10,
    optimizer_kwargs={"lr": 1e-3},
    random_state=0,
    training_length=300,
    input_chunk_length=300,
    likelihood=GaussianLikelihood(),
)

# %%
model_en.fit(series=train_en_transformed, future_covariates=train_day, verbose=True)
# Out:
# Training: 0it [00:00, ?it/s]
# RNNModel(model=LSTM, hidden_dim=20, n_rnn_layers=2, dropout=0.2, training_length=300, batch_size=16, n_epochs=10, optimizer_kwargs={'lr': 0.001}, random_state=0, input_chunk_length=300, likelihood=GaussianLikelihood(prior_mu=None, prior_sigma=None, prior_strength=1.0, beta_nll=0.0))

# %%
backtest_en = model_en.historical_forecasts(
    series=day_scaled,
    future_covariates=day_series,
    num_samples=50,
    start=0.7,
    forecast_horizon=30,
    stride=5,
    retrain=False,
    verbose=True,
)
# Out:
#   0%|          | 0/83 [00:00<?, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
plt.figure(figsize=(10, 6))
day_scaled[1000:].plot(label="actual")
backtest_en.plot(label="backtest (H=30)", low_quantile=0.01, high_quantile=0.99)
plt.legend()
